# %%
import pandas as pd

# %%
emp =pd.read_csv(r"D:\Learning\iBridge 360\Python Programming\pandas_csv.csv")

# %%
emp
# Out:
#     Sl. No       Name  No. Days    PPD  Payment  Unnamed: 5  Advance      Due  \
# 0      1.0      Nikil      29.5  240.0   7080.0     12400.0  15260.0  -2860.0
# 1      2.0      Kajol      28.0  190.0   5320.0         NaN      NaN      NaN
# 2      3.0      Lalto      22.5  240.0   5400.0     11100.0  15540.0  -4440.0
# 3      4.0      Adori      30.0  190.0   5700.0         NaN      NaN      NaN
# 4      5.0     Bhasan      24.0  240.0   5760.0     10130.0   9690.0    440.0
# 5      6.0       Paki      23.0  190.0   4370.0         NaN      NaN      NaN
# 6      7.0      Nayan      30.0  240.0   7200.0     22760.0  17760.0   5000.0
# 7      8.0    Apoorna      30.0  190.0   5700.0         NaN      NaN      NaN
# 8      9.0      Bisti      29.0  170.0   4930.0         NaN      NaN      NaN
# 9     10.0      Akash      29.0  170.0   4930.0         NaN      NaN      NaN
# 10    11.0    Gautham      28.5  240.0   6840.0     12255.0  15190.0  -2935.0
# ...

# %%
emp.drop(['Unnamed: 8'], axis=1)
# Out:
#     Sl. No       Name  No. Days    PPD  Payment  Unnamed: 5  Advance      Due
# 0      1.0      Nikil      29.5  240.0   7080.0     12400.0  15260.0  -2860.0
# 1      2.0      Kajol      28.0  190.0   5320.0         NaN      NaN      NaN
# 2      3.0      Lalto      22.5  240.0   5400.0     11100.0  15540.0  -4440.0
# 3      4.0      Adori      30.0  190.0   5700.0         NaN      NaN      NaN
# 4      5.0     Bhasan      24.0  240.0   5760.0     10130.0   9690.0    440.0
# 5      6.0       Paki      23.0  190.0   4370.0         NaN      NaN      NaN
# 6      7.0      Nayan      30.0  240.0   7200.0     22760.0  17760.0   5000.0
# 7      8.0    Apoorna      30.0  190.0   5700.0         NaN      NaN      NaN
# 8      9.0      Bisti      29.0  170.0   4930.0         NaN      NaN      NaN
# 9     10.0      Akash      29.0  170.0   4930.0         NaN      NaN      NaN
# 10    11.0    Gautham      28.5  240.0   6840.0     12255.0  15190.0  -2935.0
# ...

# %%
emp.drop(['Unnamed: 8'], axis=1, inplace = True)

# %%
emp
# Out:
#     Sl. No       Name  No. Days    PPD  Payment  Unnamed: 5  Advance      Due
# 0      1.0      Nikil      29.5  240.0   7080.0     12400.0  15260.0  -2860.0
# 1      2.0      Kajol      28.0  190.0   5320.0         NaN      NaN      NaN
# 2      3.0      Lalto      22.5  240.0   5400.0     11100.0  15540.0  -4440.0
# 3      4.0      Adori      30.0  190.0   5700.0         NaN      NaN      NaN
# 4      5.0     Bhasan      24.0  240.0   5760.0     10130.0   9690.0    440.0
# 5      6.0       Paki      23.0  190.0   4370.0         NaN      NaN      NaN
# 6      7.0      Nayan      30.0  240.0   7200.0     22760.0  17760.0   5000.0
# 7      8.0    Apoorna      30.0  190.0   5700.0         NaN      NaN      NaN
# 8      9.0      Bisti      29.0  170.0   4930.0         NaN      NaN      NaN
# 9     10.0      Akash      29.0  170.0   4930.0         NaN      NaN      NaN
# 10    11.0    Gautham      28.5  240.0   6840.0     12255.0  15190.0  -2935.0
# ...

# %%
emp.drop(['Due'], axis=1, inplace = True)

# %%
emp
# Out:
#     Sl. No       Name  No. Days    PPD  Payment  Unnamed: 5  Advance
# 0      1.0      Nikil      29.5  240.0   7080.0     12400.0  15260.0
# 1      2.0      Kajol      28.0  190.0   5320.0         NaN      NaN
# 2      3.0      Lalto      22.5  240.0   5400.0     11100.0  15540.0
# 3      4.0      Adori      30.0  190.0   5700.0         NaN      NaN
# 4      5.0     Bhasan      24.0  240.0   5760.0     10130.0   9690.0
# 5      6.0       Paki      23.0  190.0   4370.0         NaN      NaN
# 6      7.0      Nayan      30.0  240.0   7200.0     22760.0  17760.0
# 7      8.0    Apoorna      30.0  190.0   5700.0         NaN      NaN
# 8      9.0      Bisti      29.0  170.0   4930.0         NaN      NaN
# 9     10.0      Akash      29.0  170.0   4930.0         NaN      NaN
# 10    11.0    Gautham      28.5  240.0   6840.0     12255.0  15190.0
# 11    12.0   Thathone      28.5  190.0   5415.0         NaN      NaN
# 12    13.0      Jeeth      29.0  220.0   6380.0      6380.0   7925.0
# ...

# %%
emp.pop("Unnamed: 8")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Unnamed: 8'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
emp =pd.read_csv(r"D:\Learning\iBridge 360\Python Programming\pandas_csv.csv")

# %%
emp
# Out:
#     Sl. No       Name  No. Days    PPD  Payment  Unnamed: 5  Advance      Due  \
# 0      1.0      Nikil      29.5  240.0   7080.0     12400.0  15260.0  -2860.0
# 1      2.0      Kajol      28.0  190.0   5320.0         NaN      NaN      NaN
# 2      3.0      Lalto      22.5  240.0   5400.0     11100.0  15540.0  -4440.0
# 3      4.0      Adori      30.0  190.0   5700.0         NaN      NaN      NaN
# 4      5.0     Bhasan      24.0  240.0   5760.0     10130.0   9690.0    440.0
# 5      6.0       Paki      23.0  190.0   4370.0         NaN      NaN      NaN
# 6      7.0      Nayan      30.0  240.0   7200.0     22760.0  17760.0   5000.0
# 7      8.0    Apoorna      30.0  190.0   5700.0         NaN      NaN      NaN
# 8      9.0      Bisti      29.0  170.0   4930.0         NaN      NaN      NaN
# 9     10.0      Akash      29.0  170.0   4930.0         NaN      NaN      NaN
# 10    11.0    Gautham      28.5  240.0   6840.0     12255.0  15190.0  -2935.0
# ...

# %%
emp.pop("Unnamed: 8")
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# Name: Unnamed: 8, dtype: float64

# %%
emp
# Out:
#     Sl. No       Name  No. Days    PPD  Payment  Unnamed: 5  Advance      Due
# 0      1.0      Nikil      29.5  240.0   7080.0     12400.0  15260.0  -2860.0
# 1      2.0      Kajol      28.0  190.0   5320.0         NaN      NaN      NaN
# 2      3.0      Lalto      22.5  240.0   5400.0     11100.0  15540.0  -4440.0
# 3      4.0      Adori      30.0  190.0   5700.0         NaN      NaN      NaN
# 4      5.0     Bhasan      24.0  240.0   5760.0     10130.0   9690.0    440.0
# 5      6.0       Paki      23.0  190.0   4370.0         NaN      NaN      NaN
# 6      7.0      Nayan      30.0  240.0   7200.0     22760.0  17760.0   5000.0
# 7      8.0    Apoorna      30.0  190.0   5700.0         NaN      NaN      NaN
# 8      9.0      Bisti      29.0  170.0   4930.0         NaN      NaN      NaN
# 9     10.0      Akash      29.0  170.0   4930.0         NaN      NaN      NaN
# 10    11.0    Gautham      28.5  240.0   6840.0     12255.0  15190.0  -2935.0
# ...

# %%
emp
# Out:
#     Sl. No       Name  No. Days    PPD  Payment  Unnamed: 5  Advance      Due
# 0      1.0      Nikil      29.5  240.0   7080.0     12400.0  15260.0  -2860.0
# 1      2.0      Kajol      28.0  190.0   5320.0         NaN      NaN      NaN
# 2      3.0      Lalto      22.5  240.0   5400.0     11100.0  15540.0  -4440.0
# 3      4.0      Adori      30.0  190.0   5700.0         NaN      NaN      NaN
# 4      5.0     Bhasan      24.0  240.0   5760.0     10130.0   9690.0    440.0
# 5      6.0       Paki      23.0  190.0   4370.0         NaN      NaN      NaN
# 6      7.0      Nayan      30.0  240.0   7200.0     22760.0  17760.0   5000.0
# 7      8.0    Apoorna      30.0  190.0   5700.0         NaN      NaN      NaN
# 8      9.0      Bisti      29.0  170.0   4930.0         NaN      NaN      NaN
# 9     10.0      Akash      29.0  170.0   4930.0         NaN      NaN      NaN
# 10    11.0    Gautham      28.5  240.0   6840.0     12255.0  15190.0  -2935.0
# ...
